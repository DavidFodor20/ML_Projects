# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidFodor20/ML_Projects/blob/main/ML_modellek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn scipy statsmodels jupyter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 93.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
# ...

# %%
# !pip install xgboost lightgbm catboost tensorflow torch torchvision torchaudio transformers datasets opendatasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 31.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Adathalmaz megnyitása

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')

# %%
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# ##Adatszétosztás X és Y halmazra

# %%
y=df["logS"]

# %%
x=df.drop('logS', axis=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 643   3.61260  296.410                0.0            0.272727
# 722   6.48760  226.448               13.0            0.000000
# 570   3.15380  284.746                1.0            0.600000
# 66    0.77880   74.123                2.0            0.000000
# 1002  1.82140  102.177                3.0            0.000000
# ...       ...      ...                ...                 ...
# 1044  2.82960  253.305                1.0            0.631579
# 1095  2.10750  218.322                3.0            0.000000
# 1130  4.14820  335.282                7.0            0.260870
# 860   4.25720  275.179                4.0            0.352941
# 1126  6.25676  368.369                6.0            0.692308
#
# [915 rows x 4 columns]

# %% [markdown]
# # Modell építése

# %% [markdown]
# ##Linearis regresszio

# %%
import sklearn.linear_model
import LinearRegression

# %%
lr = sklearn.linear_model.LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_lr_test_pred=lr.predict(X_test)
y_lr_train_pred=lr.predict(X_train)

# %%
# Out:
# array([ -4.47026156,  -5.88839323,  -4.22029229,  -0.79352323,
#         -1.73062942,  -1.26187649,  -1.43969557,  -2.36087206,
#         -2.77481055,  -2.23755209,  -4.15424648,  -8.49226359,
#         -4.26355722,  -1.5773174 ,  -2.61749814,  -0.72935686,
#         -3.18513222,  -3.71048234,  -1.57995763,  -5.11539503,
#         -1.90340063,  -4.18841892,  -4.85523085,  -2.13317387,
#         -3.34701685,  -3.45842365,  -3.73715663,  -3.61882675,
#         -3.02530867,  -2.82178231,  -1.54861269,  -2.73630968,
#         -1.79353838,  -6.49056433,  -2.19068424,  -4.10802907,
#         -2.7303035 ,  -2.28598248,  -2.60739155,  -3.64519507,
#         -2.65218678,  -4.35285798,   1.91721982,  -3.70871993,
#         -3.50138017,  -2.71898539,  -4.77720737,  -3.38184768,
#         -1.71815824,  -2.79713356,  -5.26774517,  -2.96884167,
#         -2.27709013,  -2.76017539,  -2.12748391,  -2.3140745 ,
#         -7.74681081,  -3.21253144,  -1.76376134,  -4.17337487,
# ...

# %% [markdown]
# ##Kiértékelés

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
lr_train_mse=mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2=r2_score(y_train, y_lr_train_pred)

lr_test_mse=mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2=r2_score(y_test, y_lr_test_pred)

# %%
lr_results=pd.DataFrame([['Linear Regression',lr_train_mse,lr_train_r2,lr_test_mse,lr_test_r2]],
                        columns=['Method','Training MSE','Training R2','Test MSE','Test R2'])

# %%
lr_results
# Out:
#               Method  Training MSE  Training R2  Test MSE   Test R2
# 0  Linear Regression      1.013989     0.769513  0.999084  0.770565

# %% [markdown]
# ##RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(max_depth=2, random_state=42)

# %% [markdown]
# ###Modell illesztés

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=42)

# %%
y_rf_train_pred=rf.predict(X_train)
y_rf_test_pred=rf.predict(X_test)

# %%
rf_train_mse=mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2=r2_score(y_train, y_rf_train_pred)

rf_test_mse=mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2=r2_score(y_test, y_rf_test_pred)

rf.results=pd.DataFrame([["RandomForest", rf_train_mse, rf_train_r2,rf_test_mse, rf_test_r2 ]])
rf.results.columns=["Method", "Train MSE", "Train R2", "Test MSE", "Test R2"]
rf.results
# Out:
#          Method  Train MSE  Train R2  Test MSE   Test R2
# 0  RandomForest   1.050251   0.76127  1.046995  0.759562

# %% [markdown]
# #Modellek összehasonlítása

# %% [markdown]
# ###RandomForest accuracy

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = rf
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([-1.3275458 , -6.99230664, -4.42115215, -2.58316439, -1.39804237,
#        -5.35572688, -1.37059365, -4.18145058, -2.37855272, -4.37853402,
#        -1.39804237, -1.39804237, -2.66448365, -2.84053097, -3.68413052,
#        -1.48260587, -2.44587069, -4.39718433, -1.22055445, -2.63703494,
#        -2.46404701, -1.37059365, -4.39718433, -3.48102593, -1.17942941,
#        -1.17942941, -2.44587069, -5.35572688, -2.59744911, -4.16271855,
#        -1.48260587, -2.66448365, -4.39718433, -1.88894534, -2.63703494,
#        -7.01733129, -1.17942941, -2.39625715, -2.20457108, -1.82194807,
#        -1.88894534, -7.01733129, -1.39804237, -1.26399291, -2.20457108,
#        -4.37853402, -4.02848446, -1.39804237, -1.17942941, -1.4117187 ,
#        -3.56333831, -2.63703494, -1.39804237, -1.54615877, -7.01733129,
#        -5.51972342, -4.01323226, -3.68413052, -1.3007457 , -1.39804237,
#        -4.39718433, -4.42115215, -1.17942941, -1.37136682, -2.21860159,
# ...
